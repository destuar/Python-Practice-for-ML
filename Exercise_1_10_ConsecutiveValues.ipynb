# %% [markdown]
# Link to Medium blog post: https://towardsdatascience.com/pandas-dataframe-group-by-consecutive-certain-values-a6ed8e5d8cc

# %%
import pandas as pd

# %%
# Let’s create the sample DataFrame
df = pd.DataFrame({
  'item':['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M'], 
  'value':[12, 3, 5, 0, 0, 0, 23, 4, 2, 0, 0, 12, 0]
})
df
# Out:
#    item  value
# 0     A     12
# 1     B      3
# 2     C      5
# 3     D      0
# 4     E      0
# 5     F      0
# 6     G     23
# 7     H      4
# 8     I      2
# 9     J      0
# 10    K      0
# 11    L     12
# 12    M      0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df[df['value'] == 0].groupby((df['value'] != 0).cumsum())

# %%
for k, v in df[df['value'] == 0].groupby((df['value'] != 0).cumsum()):
    print(f'[group {k}]')
    print(v)
    print('\n')
# Out:
# [group 3]
#   item  value
# 3    D      0
# 4    E      0
# 5    F      0
#
#
# [group 6]
#    item  value
# 9     J      0
# 10    K      0
#
#
# [group 7]
#    item  value
# 12    M      0
