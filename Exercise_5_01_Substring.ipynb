# %% [markdown]
# Link to Medium blog post: https://towardsdatascience.com/check-for-a-substring-in-a-pandas-dataframe-column-4b949f64852

# %% [markdown]
# # Check For a Substring in a Pandas DataFrame Column

# %% [markdown]
# The Pandas library is a comprehensive tool not only for crunching numbers but also for working with text data.
#
# For many data analysis applications and machine learning exploration/pre-processing, you’ll want to either filter out or extract information from text data. To do so, Pandas offers a wide range of in-built methods that you can use to add, remove, and edit text columns in your DataFrames.
#
# In this piece, let’s take a look specifically at searching for substrings in a DataFrame column. This may come in handy when you need to create a new category based on existing data (for example during feature engineering before training a machine learning model).

# %%
import pandas as pd
df = pd.read_csv('vgsales.csv')

df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %% [markdown]
# ## Using “contains” to Find a Substring in a Pandas DataFrame

# %% [markdown]
# The contains method in Pandas allows you to search a column for a specific substring. The contains method returns boolean values for the Series with True for if the original Series value contains the substring and False if not. A basic application of contains should look like Series.str.contains("substring"). However, we can immediately take this to the next level with two additions:
#
# 1. Using the case argument to specify whether to match on string case;
# 2. Using the returned Series of boolean values as a mask to get a subset of the DataFrame.
#
# Applying these two should look like this:

# %%
pokemon_games = df.loc[df['Name'].str.contains("pokemon", case=False)]

pokemon_games
# Out:
#         Rank                                               Name Platform  \
# 4          5                           Pokemon Red/Pokemon Blue       GB
# 12        13                        Pokemon Gold/Pokemon Silver       GB
# 20        21                      Pokemon Diamond/Pokemon Pearl       DS
# 25        26                      Pokemon Ruby/Pokemon Sapphire      GBA
# 26        27                        Pokemon Black/Pokemon White       DS
# 32        33                                Pokemon X/Pokemon Y      3DS
# 45        46               Pokemon HeartGold/Pokemon SoulSilver       DS
# 49        50          Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS
# 58        59                  Pokemon FireRed/Pokemon LeafGreen      GBA
# 81        82                    Pokemon Black 2/Pokemon White 2       DS
# 165      166                                    Pokemon Stadium      N64
# 171      172                                    Pokemon Pinball       GB
# 209      210  Pokemon Mystery Dungeon: Explorers of Time/Exp...       DS
# 346      347                                       Pokemon Snap      N64
# 692      694                   Pokemon Ranger: Shadows of Almia       DS
# 750      752                                     Pokemon Ranger       DS
# 816      818      Pokemon Mystery Dungeon: Red/Blue Rescue Team      GBA
# 1139    1141                          Pokemon Battle Revolution      Wii
# 1178    1180          Pokemon Mystery Dungeon: Explorers of Sky       DS
# 1192    1194                   Pokemon Pinball: Ruby & Sapphire      GBA
# 1481    1483                     Pokemon Ranger: Guardian Signs       DS
# 1555    1557         Pokemon Mystery Dungeon: Gates to Infinity      3DS
# 1591    1593                       Pokemon XD: Gale of Darkness       GC
# 1702    1704                      Pokemon Super Mystery Dungeon      3DS
# 1781    1783                               Pokemon Rumble Blast      3DS
# 1986    1988                                   Pokemon Conquest       DS
# 2336    2338              Pokemon Card GB2: Here Comes Team GR!       GB
# 2681    2683                                       Pokemon Dash       DS
# 3381    3383                                    Pokemon Trozei!       DS
# 4044    4046                                Pokemon Art Academy      3DS
# 4365    4367                              Pokemon Puzzle League      N64
# 5050    5052                                    Pokemon Channel       GC
# 6098    6100                    Battle & Get! Pokemon Typing DS       DS
# 6231    6233                       Pokemon Box: Ruby & Sapphire       GC
# 10992  10994                               Pokemon Rumble World      3DS
#
#          Year         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 4      1996.0  Role-Playing  Nintendo     11.27      8.89     10.22
# 12     1999.0  Role-Playing  Nintendo      9.00      6.18      7.20
# 20     2006.0  Role-Playing  Nintendo      6.42      4.52      6.04
# 25     2002.0  Role-Playing  Nintendo      6.06      3.90      5.38
# 26     2010.0  Role-Playing  Nintendo      5.57      3.28      5.65
# 32     2013.0  Role-Playing  Nintendo      5.17      4.05      4.34
# 45     2009.0        Action  Nintendo      4.40      2.77      3.96
# 49     2014.0  Role-Playing  Nintendo      4.23      3.37      3.08
# 58     2004.0  Role-Playing  Nintendo      4.34      2.65      3.15
# 81     2012.0  Role-Playing  Nintendo      2.91      1.86      3.14
# 165    1999.0      Strategy  Nintendo      3.18      1.24      0.94
# 171    1999.0          Misc  Nintendo      3.02      1.12      1.01
# 209    2007.0  Role-Playing  Nintendo      1.85      1.20      1.54
# 346    1999.0    Simulation  Nintendo      2.23      0.68      0.66
# 692    2008.0  Role-Playing  Nintendo      0.95      0.54      0.62
# 750    2006.0  Role-Playing  Nintendo      1.29      0.04      0.73
# 816    2005.0  Role-Playing  Nintendo      0.71      0.52      0.74
# 1139   2006.0  Role-Playing  Nintendo      0.80      0.38      0.30
# 1178   2009.0  Role-Playing  Nintendo      0.58      0.44      0.44
# 1192   2003.0          Misc  Nintendo      0.68      0.38      0.44
# 1481   2010.0  Role-Playing  Nintendo      0.51      0.17      0.58
# 1555   2012.0  Role-Playing  Nintendo      0.44      0.30      0.47
# 1591   2005.0  Role-Playing  Nintendo      0.71      0.19      0.31
# 1702   2015.0  Role-Playing  Nintendo      0.46      0.31      0.33
# 1781   2011.0        Action  Nintendo      0.47      0.26      0.35
# 1986   2012.0  Role-Playing  Nintendo      0.58      0.06      0.37
# 2336   2001.0      Strategy  Nintendo      0.00      0.00      0.89
# 2681   2004.0        Racing  Nintendo      0.21      0.14      0.38
# 3381   2005.0        Puzzle  Nintendo      0.26      0.00      0.31
# 4044   2014.0          Misc  Nintendo      0.18      0.12      0.16
# 4365   2000.0        Puzzle  Nintendo      0.36      0.08      0.00
# 5050   2003.0     Adventure  Nintendo      0.24      0.06      0.07
# 6098   2011.0          Misc  Nintendo      0.00      0.00      0.29
# 6231   2003.0          Misc  Nintendo      0.00      0.00      0.27
# 10992  2015.0        Action  Nintendo      0.00      0.01      0.08
#
#        Other_Sales  Global_Sales
# 4             1.00         31.37
# 12            0.71         23.10
# 20            1.37         18.36
# 25            0.50         15.85
# 26            0.82         15.32
# 32            0.79         14.35
# 45            0.77         11.90
# 49            0.65         11.33
# 58            0.35         10.49
# 81            0.43          8.33
# 165           0.09          5.45
# 171           0.16          5.31
# 209           0.37          4.96
# 346           0.06          3.63
# 692           0.18          2.30
# 750           0.12          2.18
# 816           0.08          2.06
# 1139          0.13          1.61
# 1178          0.12          1.58
# 1192          0.05          1.56
# 1481          0.06          1.33
# 1555          0.06          1.27
# 1591          0.03          1.25
# 1702          0.08          1.19
# 1781          0.07          1.14
# 1986          0.04          1.05
# 2336          0.00          0.89
# 2681          0.04          0.77
# 3381          0.02          0.60
# 4044          0.03          0.49
# 4365          0.01          0.45
# 5050          0.01          0.38
# 6098          0.00          0.29
# 6231          0.01          0.28
# 10992         0.00          0.09

# %% [markdown]
# Using the loc method allows us to get only the values in the DataFrame that contain the string “pokemon”. We’ve simply used the contains method to acquire True and False values based on whether the “Name” column includes our substring and then returned only the True values.

# %% [markdown]
# ## Using regex with the “contains” method in Pandas

# %% [markdown]
# In addition to just matching on a regular substring, we can also use contains to match on regular expressions. We’ll use the exact same format as before, except this time let’s use a bit of regex to only find the story-based Pokemon games (i.e. excluding Pokemon Pinball and the like).

# %%
pokemon_og_games = df.loc[df['Name'].str.contains("pokemon \w{1,}/", case=False)]

pokemon_og_games
# Out:
#     Rank                                  Name Platform    Year         Genre  \
# 4      5              Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# 12    13           Pokemon Gold/Pokemon Silver       GB  1999.0  Role-Playing
# 20    21         Pokemon Diamond/Pokemon Pearl       DS  2006.0  Role-Playing
# 25    26         Pokemon Ruby/Pokemon Sapphire      GBA  2002.0  Role-Playing
# 26    27           Pokemon Black/Pokemon White       DS  2010.0  Role-Playing
# 32    33                   Pokemon X/Pokemon Y      3DS  2013.0  Role-Playing
# 45    46  Pokemon HeartGold/Pokemon SoulSilver       DS  2009.0        Action
# 58    59     Pokemon FireRed/Pokemon LeafGreen      GBA  2004.0  Role-Playing
#
#    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 4   Nintendo     11.27      8.89     10.22         1.00         31.37
# 12  Nintendo      9.00      6.18      7.20         0.71         23.10
# 20  Nintendo      6.42      4.52      6.04         1.37         18.36
# 25  Nintendo      6.06      3.90      5.38         0.50         15.85
# 26  Nintendo      5.57      3.28      5.65         0.82         15.32
# 32  Nintendo      5.17      4.05      4.34         0.79         14.35
# 45  Nintendo      4.40      2.77      3.96         0.77         11.90
# 58  Nintendo      4.34      2.65      3.15         0.35         10.49

# %% [markdown]
# Above, I just used some simple regex to find strings that matched the pattern of “pokemon” + “one character or more” + “/”. The result of the new mask returned rows including “Pokemon Red/Pokemon Blue”, “Pokemon Gold/Pokemon Silver”, and more.

# %% [markdown]
# Next, let’s do another quick example of using regex to find all Sports games with “football” or “soccer” in its name. First, we’ll use a simple conditional statement to filter out all rows with the a genre of “sports”:

# %%
sports_games = df.loc[df['Genre'] == 'Sports']

sports_games
# Out:
#         Rank                           Name Platform    Year   Genre  \
# 0          1                     Wii Sports      Wii  2006.0  Sports
# 3          4              Wii Sports Resort      Wii  2009.0  Sports
# 13        14                        Wii Fit      Wii  2007.0  Sports
# 14        15                   Wii Fit Plus      Wii  2009.0  Sports
# 77        78                        FIFA 16      PS4  2015.0  Sports
# ...      ...                            ...      ...     ...     ...
# 16576  16579              Rugby Challenge 3     XOne  2016.0  Sports
# 16578  16581  Outdoors Unleashed: Africa 3D      3DS  2011.0  Sports
# 16579  16582              PGA European Tour      N64  2000.0  Sports
# 16581  16584                      Fit & Fun      Wii  2011.0  Sports
# 16587  16590       Mezase!! Tsuri Master DS       DS  2009.0  Sports
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                  Nintendo     41.49     29.02      3.77         8.46
# 3                  Nintendo     15.75     11.01      3.28         2.96
# 13                 Nintendo      8.94      8.03      3.60         2.15
# 14                 Nintendo      9.09      8.59      2.53         1.79
# 77          Electronic Arts      1.11      6.06      0.06         1.26
# ...                     ...       ...       ...       ...          ...
# 16576  Alternative Software      0.00      0.01      0.00         0.00
# 16578               Mastiff      0.01      0.00      0.00         0.00
# 16579            Infogrames      0.01      0.00      0.00         0.00
# 16581               Unknown      0.00      0.01      0.00         0.00
# 16587           Hudson Soft      0.00      0.00      0.01         0.00
#
#        Global_Sales
# 0             82.74
# 3             33.00
# 13            22.72
# 14            22.00
# 77             8.49
# ...             ...
# 16576          0.01
# 16578          0.01
# 16579          0.01
# 16581          0.01
# 16587          0.01
#
# [2346 rows x 11 columns]

# %% [markdown]
# You’ll notice that above there was no real need to match on a substring or use regex, because we were simply selecting rows based on a category. However, when matching on the row name, we’ll need to be searching different types of strings for a substring, which is where regex comes in handy. To do so, we’ll do the following:

# %%
football_soccer_games = sports_games.loc[df['Name'].str.contains("soccer|football", case=False)]

football_soccer_games
# Out:
#         Rank                                       Name Platform    Year  \
# 199      200                             FIFA Soccer 11      PS3  2010.0
# 249      250  Winning Eleven: Pro Evolution Soccer 2007      PS2  2006.0
# 269      270                             FIFA Soccer 06      PS2  2005.0
# 283      284                             FIFA Soccer 07      PS2  2006.0
# 292      293              World Soccer Winning Eleven 9      PS2  2005.0
# ...      ...                                        ...      ...     ...
# 16076  16079                               Fab 5 Soccer       DS  2008.0
# 16118  16121                      Football Manager 2005       PC  2004.0
# 16400  16403                  Pro Evolution Soccer 2010       PC  2009.0
# 16420  16423  Winning Eleven: Pro Evolution Soccer 2007       PC  2006.0
# 16558  16561                  Pro Evolution Soccer 2008       PC  2007.0
#
#         Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 199    Sports               Electronic Arts      0.60      3.29      0.06
# 249    Sports  Konami Digital Entertainment      0.10      2.39      1.05
# 269    Sports               Electronic Arts      0.78      2.55      0.04
# 283    Sports               Electronic Arts      0.71      2.48      0.03
# 292    Sports  Konami Digital Entertainment      0.12      2.26      0.90
# ...       ...                           ...       ...       ...       ...
# 16076  Sports                     Destineer      0.01      0.00      0.00
# 16118  Sports                          Sega      0.00      0.01      0.00
# 16400  Sports  Konami Digital Entertainment      0.00      0.01      0.00
# 16420  Sports  Konami Digital Entertainment      0.00      0.01      0.00
# 16558  Sports  Konami Digital Entertainment      0.00      0.01      0.00
#
#        Other_Sales  Global_Sales
# 199           1.13          5.08
# 249           0.86          4.39
# 269           0.84          4.21
# 283           0.89          4.11
# 292           0.77          4.06
# ...            ...           ...
# 16076         0.00          0.01
# 16118         0.00          0.01
# 16400         0.00          0.01
# 16420         0.00          0.01
# 16558         0.00          0.01
#
# [299 rows x 11 columns]

# %% [markdown]
# Now we’ve gotten a DataFrame with just the games that have a name including “soccer” or “football”. We simply made use of the “|” regex “or” operator that allows you to match on a string that contains one or another substring.

# %% [markdown]
# So we’ve successfully gotten a DataFrame with only names that contain either “football” or “soccer”, but we don’t actually know which of those two strings it contains. If we wanted to know which of the two it contained, we could use the findall method on the name column and assign the returned values to a new column in the DataFrame.
#
# The findall method returns matches of the pattern of regular expression you specify in each string of the Series you call it on. The format is largely the same as the contains method, except you’ll need to import re to not match on string case.

# %%
import re
football_soccer_games['Football/Soccer'] = football_soccer_games['Name'].str.findall('football|soccer', flags=re.IGNORECASE)

football_soccer_games
# Out:
# /var/folders/cz/dg_zmrb96h979_06qv2zwrf40000gn/T/ipykernel_46796/757613603.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   football_soccer_games['Football/Soccer'] = football_soccer_games['Name'].str.findall('football|soccer', flags=re.IGNORECASE)
#         Rank                                       Name Platform    Year  \
# 199      200                             FIFA Soccer 11      PS3  2010.0
# 249      250  Winning Eleven: Pro Evolution Soccer 2007      PS2  2006.0
# 269      270                             FIFA Soccer 06      PS2  2005.0
# 283      284                             FIFA Soccer 07      PS2  2006.0
# 292      293              World Soccer Winning Eleven 9      PS2  2005.0
# ...      ...                                        ...      ...     ...
# 16076  16079                               Fab 5 Soccer       DS  2008.0
# 16118  16121                      Football Manager 2005       PC  2004.0
# 16400  16403                  Pro Evolution Soccer 2010       PC  2009.0
# 16420  16423  Winning Eleven: Pro Evolution Soccer 2007       PC  2006.0
# 16558  16561                  Pro Evolution Soccer 2008       PC  2007.0
#
#         Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 199    Sports               Electronic Arts      0.60      3.29      0.06
# 249    Sports  Konami Digital Entertainment      0.10      2.39      1.05
# 269    Sports               Electronic Arts      0.78      2.55      0.04
# 283    Sports               Electronic Arts      0.71      2.48      0.03
# 292    Sports  Konami Digital Entertainment      0.12      2.26      0.90
# ...       ...                           ...       ...       ...       ...
# 16076  Sports                     Destineer      0.01      0.00      0.00
# 16118  Sports                          Sega      0.00      0.01      0.00
# 16400  Sports  Konami Digital Entertainment      0.00      0.01      0.00
# 16420  Sports  Konami Digital Entertainment      0.00      0.01      0.00
# 16558  Sports  Konami Digital Entertainment      0.00      0.01      0.00
#
#        Other_Sales  Global_Sales Football/Soccer
# 199           1.13          5.08        [Soccer]
# 249           0.86          4.39        [Soccer]
# 269           0.84          4.21        [Soccer]
# 283           0.89          4.11        [Soccer]
# 292           0.77          4.06        [Soccer]
# ...            ...           ...             ...
# 16076         0.00          0.01        [Soccer]
# 16118         0.00          0.01      [Football]
# 16400         0.00          0.01        [Soccer]
# 16420         0.00          0.01        [Soccer]
# 16558         0.00          0.01        [Soccer]
#
# [299 rows x 12 columns]

# %% [markdown]
# You’ll see at the end of the returned DataFrame a new column that contains either “Soccer” or “Football”, depending on which of the two the videogame name contains. This can be helpful if you need to create new columns based on the existing columns and using values from those columns.

# %% [markdown]
# Finally, for a quick trick to exclude strings with just one additional operator on top of the basic contains method, let’s try to get all the football and soccer games that don’t include “FIFA” in the name.

# %%
not_fifa = football_soccer_games.loc[~football_soccer_games['Name'].str.contains('FIFA')]

not_fifa
# Out:
#         Rank                                         Name Platform    Year  \
# 249      250    Winning Eleven: Pro Evolution Soccer 2007      PS2  2006.0
# 292      293                World Soccer Winning Eleven 9      PS2  2005.0
# 315      316  World Soccer Winning Eleven 8 International      PS2  2004.0
# 348      349                    Pro Evolution Soccer 2008      PS2  2007.0
# 474      475  World Soccer Winning Eleven 6 International      PS2  2002.0
# ...      ...                                          ...      ...     ...
# 16076  16079                                 Fab 5 Soccer       DS  2008.0
# 16118  16121                        Football Manager 2005       PC  2004.0
# 16400  16403                    Pro Evolution Soccer 2010       PC  2009.0
# 16420  16423    Winning Eleven: Pro Evolution Soccer 2007       PC  2006.0
# 16558  16561                    Pro Evolution Soccer 2008       PC  2007.0
#
#         Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 249    Sports  Konami Digital Entertainment      0.10      2.39      1.05
# 292    Sports  Konami Digital Entertainment      0.12      2.26      0.90
# 315    Sports  Konami Digital Entertainment      0.16      1.89      1.12
# 348    Sports  Konami Digital Entertainment      0.05      0.00      0.64
# 474    Sports  Konami Digital Entertainment      0.12      1.26      1.16
# ...       ...                           ...       ...       ...       ...
# 16076  Sports                     Destineer      0.01      0.00      0.00
# 16118  Sports                          Sega      0.00      0.01      0.00
# 16400  Sports  Konami Digital Entertainment      0.00      0.01      0.00
# 16420  Sports  Konami Digital Entertainment      0.00      0.01      0.00
# 16558  Sports  Konami Digital Entertainment      0.00      0.01      0.00
#
#        Other_Sales  Global_Sales Football/Soccer
# 249           0.86          4.39        [Soccer]
# 292           0.77          4.06        [Soccer]
# 315           0.68          3.85        [Soccer]
# 348           2.93          3.63        [Soccer]
# 474           0.45          2.99        [Soccer]
# ...            ...           ...             ...
# 16076         0.00          0.01        [Soccer]
# 16118         0.00          0.01      [Football]
# 16400         0.00          0.01        [Soccer]
# 16420         0.00          0.01        [Soccer]
# 16558         0.00          0.01        [Soccer]
#
# [235 rows x 12 columns]

# %% [markdown]
# As you can see, we’ve simply made use of the ~ operator that allows us to take all the False values of the mask inside the loc method.
